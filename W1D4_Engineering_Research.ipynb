# %% [markdown]
# <a href="https://colab.research.google.com/github/inspire2029-sudo/phantoms-ai-week1/blob/main/W1D4_Engineering_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **` العنوان الرئيسي`**

# %% [markdown]
# # **# W1D4 Engineering Research**

# %% [markdown]
# ### **`مقدمة`**

# %% [markdown]
# في التاسك ده هنقارن بين شوية اختيارات بنستخدمها في الشغل البرمجي ونحدد إيه الأنسب لطريقة شغل التيم
#
# هنناقش اختيار بيئة التطوير وأهمية الفيرتشوال إنفيرومنت واستراتيجية الجيت برانشينج
#
# الهدف مش إننا نختار أداة لمجرد إنها مشهورة لكن نفهم ليه الاختيار مناسب لطبيعة المشروع وطريقة شغل التيم

# %% [markdown]
# ### **` اختيار بيئة التطوير`**

# %% [markdown]
# إحنا قدامنا أكتر من اختيار نقدر نشتغل بيه زي <في إس كود> و <باي تشارم> و <جوجل كولاب>
#
# ومش شايفة إن فيه اختيار واحد ينفع نقول عليه الأفضل في كل الحالات لأن كل أداة فيهم بتخدم طريقة شغل مختلفة

# %% [markdown]
# ### **`<في إس كود>`**

# %% [markdown]
# <في إس كود> مناسب جدًا لما المشروع يبدأ يكبر ومابقاش مجرد ملف واحد أو تجربة صغيرة
#
#
#
# يعني بدل ما أكون شغالة في <نوت بوك> واحدة ممكن يبقى عندي كذا ملف وكذا جزء من المشروع
#
# وفيه <جيت> ومكتبات وملفات إعدادات واختبارات وكود محتاج يتعمله <ديباجينج>
#
#
#
# الميزة المهمة بالنسبالي إن <في إس كود> أقدر أربطه بـ <أوبونتو> عن طريق <دابليو إس إل>
#
#
#
# وده بيسمحلي أكتب الكود من <في إس كود> وفي نفس الوقت أشغله جوه بيئة <لينكس>
#
#
#
# وده قريب جدًا من طريقة الشغل اللي ممكن أقابلها بعد كده في مشاريع حقيقية لأن كتير من أدوات السيرفرات والـ <ديبلويمنت> والـ <دوكر> بتكون معتمدة على بيئة <لينكس>
#
#
#
# كمان أقدر أتحكم في نسخة <بايثون> اللي المشروع بيستخدمها وأعمل <فيرتشوال إنفيرومنت> وأثبت المكتبات اللي المشروع محتاجها وأتعامل مع <جيت> من نفس المكان
#
#
#
# وعشان كده أنا شخصيًا أفضل <في إس كود> مع <أوبونتو> في التطوير اليومي
#
#
#
# مش لأن الأداة أحسن بشكل مطلق ولكن لأنها مناسبة أكتر لطريقة الشغل اللي أنا عايزة أتعود عليها

# %% [markdown]
# ### **`<باي تشارم>`**

# %% [markdown]
# <باي تشارم> اختيار قوي جدًا لو المشروع معتمد بشكل أساسي على <بايثون>
#
# هو معمول مخصوص للتطوير باستخدام <بايثون> وفيه أدوات قوية للـ <ديباجينج> وإدارة المشاريع والـ <جيت> والـ <فيرتشوال إنفيرومنت>
#
# فلو عندنا مشروع كبير كله تقريبًا <بايثون> ممكن يكون اختيار مناسب جدًا
#
# لكن بالنسبة ليا أنا محتاجة بيئة أقدر أتعامل فيها مع <بايثون> وفي نفس الوقت <لينكس> و <جيت> وأدوات تانية زي <دوكر> وغيرها
#
# وعشان كده <في إس كود> بيديني المرونة اللي محتاجاها أكتر

# %% [markdown]
# ### **` <جوجل كولاب>`**

# %% [markdown]
# <جوجل كولاب> مختلف شوية عن <في إس كود> و <باي تشارم>
#
# هو أساسًا بيئة شغل على السحابة مبنية على فكرة <جوبتر نوت بوك>
#
# وده مناسب جدًا للتجارب السريعة والـ <داتا ساينس> والـ <ماشين ليرننج>
#
# ومن مميزاته إننا نقدر نبدأ تشغيل <بايثون> من غير ما كل واحد يجهز البيئة عنده من البداية
#
# وكمان مشاركة الـ <نوت بوك> مع باقي أعضاء التيم سهلة
#
# وده مناسب جدًا للتاسكات الحالية لأننا بنتعلم ونجرب وننفذ حاجات صغيرة ومش محتاجين من البداية نعمل <بروجكت ستركتشر> كبير
#
# لكن فيه فرق مهم
#
# <جوجل كولاب> بيعتمد على بيئة تشغيل مؤقتة على السحابة
#
# يعني البيئة اللي شغالة عليها مش هي نفس فكرة إن عندي مشروع موجود بشكل دائم على جهازي
#
# وكمان الموارد المتاحة زي <جي بي يو> مش حاجة أقدر أضمن إنها هتفضل متاحة بنفس الشكل طول الوقت
#
# عشان كده شايفة إن <جوجل كولاب> مناسب جدًا للتجارب والـ <نوت بوك> والتعلم
#
# لكن لما المشروع يكبر ويبقى فيه ملفات كتير و <إيه بي آيز> و <جيت> و <دوكر> و <ديبلويمنت> هحتاج بيئة تطوير محلية أكتر زي <في إس كود> مع <أوبونتو>

# %% [markdown]
# ### **`قرار التيم`**

# %% [markdown]
# بما إن التيم اختار <جوجل كولاب> للتاسكات الحالية فأنا شايفة إن القرار منطقي
#
# لأننا حاليًا في مرحلة تعلم وتجربة وتنفيذ <نوت بوك>
#
# فمش منطقي نخلي كل شخص يقضي وقت كبير في تجهيز نفس البيئة على جهازه
#
# لكن ده مش معناه إن <جوجل كولاب> لازم يكون هو الأداة الوحيدة طول عمر المشروع
#
# ممكن نستخدم <جوجل كولاب> في التجارب والـ <ماشين ليرننج> والـ <نوت بوك>
#
# وبعدين لما المشروع يتحول لشغل برمجي أكبر نستخدم <في إس كود> مع <أوبونتو>
#
# بالنسبة ليا شخصيًا أنا أفضل <في إس كود> مع <أوبونتو> في التطوير لأن ده بيديني تحكم أكبر في البيئة وبيخليني أتعامل مع <لينكس> و <جيت> والمكتبات والملفات بشكل أقرب للشغل الحقيقي

# %% [markdown]
# ### **<`أهمية <الفيرتشوال إنفيرومنت`**

# %% [markdown]
# الـ <فيرتشوال إنفيرومنت> من الحاجات اللي ممكن في البداية نحس إنها مش ضرورية
#
# لكن أول ما المشروع يكبر أو أكتر من شخص يبدأ يشتغل عليه بتظهر أهميتها جدًا
#
# المشكلة إن كل مشروع ممكن يحتاج إصدارات مختلفة من نفس المكتبات
#
# مثلًا مشروع ممكن يحتاج إصدار معين من مكتبة
#
# ومشروع تاني يحتاج إصدار مختلف
#
# لو الاتنين متثبتين في نفس البيئة ممكن تحديث مكتبة لمشروع معين يعمل مشكلة في مشروع تاني
#
# وده من المشاكل اللي بتحصل فعلًا في مشاريع <بايثون>
#
# عشان كده كل مشروع المفروض يكون ليه بيئة منفصلة
#
# الـ <فيرتشوال إنفيرومنت> بتخليني أفصل المكتبات الخاصة بالمشروع ده عن باقي المشاريع اللي عندي

# %% [markdown]
# ### `**إزاي نضمن إن كل أعضاء التيم شغالين بشكل قريب من بعض**`

# %% [markdown]
# هنا الـ <فيرتشوال إنفيرومنت> لوحدها مش كفاية
#
# لأن لو أنا عملت بيئة عندي وإنت عملت بيئة عندك ممكن كل واحد يكون مثبت عنده إصدارات مختلفة
#
# عشان كده لازم نوثق المكتبات والإصدارات اللي المشروع محتاجها
#
# وده ممكن نعمله باستخدام ملف اسمه <ريكوايرمنتس دوت تي إكس تي>
#
# الملف ده بيحتوي على المكتبات والإصدارات المطلوبة للمشروع
#
# وبالتالي أي عضو جديد يدخل التيم يقدر يعمل <فيرتشوال إنفيرومنت> عنده ويثبت نفس المتطلبات
#
# وبكده بدل ما كل واحد يقول أنا عندي المكتبات شغالة وخلاص يبقى عندنا ملف واضح بيحدد المشروع محتاج إيه
#
# والـ <فيرتشوال إنفيرومنت> نفسها مش بنرفعها على <جيت هاب>
#
# إحنا بنرفع ملفات المشروع وملف <ريكوايرمنتس دوت تي إكس تي>
#
# وكل عضو يعمل البيئة عنده
#
# وده بيقلل مشاكل اختلاف البيئات بين أعضاء التيم

# %% [markdown]
# ### **`استراتيجية <جيت برانشينج >`**

# %% [markdown]
# لو إحنا شغالين كتيم حقيقي فمش منطقي إن كل شخص يعدل مباشرة على <مين
#
# لأن <مين> المفروض تفضل فيها النسخة المستقرة من المشروع
#
# لو كل واحد عدل عليها مباشرة ممكن تعديل من شخص يأثر على شغل باقي التيم
#
# عشان كده الأفضل إن كل شخص يشتغل على <برانش> منفصل

# %% [markdown]
# ### **`شكل الشغل`**

# %% [markdown]
# يكون عندنا <مين> كفرع أساسي
#
# وكل عضو يعمل <برانش> خاص بالتاسك أو الـ <فيتشر> اللي بيشتغل عليها
#
# مثلًا لو حد بيشتغل على جزء تسجيل الدخول ممكن يسمي الفرع
#
# <فيتشر داش لوجين>
#
# ولو حد بيصلح مشكلة ممكن يسميه
#
# <فيكس داش إيه بي آي إيرور>
#
# الفكرة إن اسم الـ <برانش> يوضح هو معمول ليه

# %% [markdown]
# ### **`بعد ما أخلص شغلي`**

# %% [markdown]
# مش أعمل <بوش> مباشر على <مين>
#
# أعمل <بوش> للـ <برانش> بتاعي
#
# وبعدها أعمل <بول ريكويست>
#
# الـ <بول ريكويست> بيخلينا نراجع التعديلات قبل ما تدخل في النسخة الأساسية
#
# حد تاني من التيم يراجع الكود
#
# يشوف هل الكود شغال
#
# هل فيه مشكلة
#
# هل فيه حاجة ممكن تتعمل بطريقة أحسن
#
# ولو فيه تعديل مطلوب أصلحه على نفس الـ <برانش>
#
# وبعد ما التعديل يبقى جاهز يتم عمل <ميرج> في <مين>

# %% [markdown]
# ### **`ليه ده مهم`**

# %% [markdown]
# لأن الـ <بول ريكويست> مش مجرد طريقة ننقل بيها الكود من فرع لفرع
#
# هو جزء من عملية مراجعة الكود
#
# وده مهم جدًا في شغل التيم لأن الشخص اللي كتب الكود ممكن يكون شايف إن كل حاجة تمام لكن شخص تاني يلاحظ مشكلة أو حالة مش واخدين بالنا منها
#
# وكمان بيخلي عندنا تاريخ واضح للتعديلات
#
# نعرف مين عمل التغيير وإيه التغيير وليه اتعمل

# %% [markdown]
# ### **`هل محتاجين نظام معقد`**

# %% [markdown]
# مش شايفة إننا محتاجين نعمل نظام معقد من أول يوم
#
# إحنا محتاجين طريقة شغل بسيطة وواضحة
#
# <مين> تفضل مستقرة
#
# كل Task أو Feature يكون ليها <برانش>
#
# كل تعديل مهم يدخل عن طريق <بول ريكويست>
#
# يبقى فيه <كود ريفيو> قبل الـ <ميرج>
#
# ولو المشروع كبر بعد كده نقدر نزود <سي آي> واختبارات تلقائية وحماية أكبر للـ <برانش>

# %% [markdown]
# ### **`الخلاصة`**

# %% [markdown]
# بعد مقارنة الاختيارات أنا شايفة إن مفيش أداة واحدة تنفع لكل مراحل المشروع
#
# بالنسبة للتاسكات الحالية <جوجل كولاب> مناسب لأنه بيسهل تشغيل الـ <نوت بوك> ومشاركة التجارب ومناسب جدًا لمرحلة التعلم والتجربة
#
# بالنسبة للتطوير اليومي أنا أفضل <في إس كود> مع <أوبونتو> لأنه بيديني تحكم أكبر في البيئة وبيخليني أتعامل مع <لينكس> و <جيت> والمكتبات وهيكلة المشروع بشكل أقرب لطريقة الشغل العملية
#
# بالنسبة للـ <فيرتشوال إنفيرومنت> هنخلي لكل مشروع بيئة منفصلة ونوثق المكتبات والإصدارات المطلوبة في <ريكوايرمنتس دوت تي إكس تي>
#
# وبالنسبة للـ <جيت> هنخلي <مين> هو الفرع الأساسي ونستخدم <فيتشر برانشز> لكل Task أو Feature وبعدها <بول ريكويست> و <كود ريفيو> قبل الدمج
#
# الهدف من القرارات دي مش إننا نستخدم أدوات مشهورة وخلاص
#
# الهدف إن طريقة الشغل نفسها تبقى منظمة وتقلل المشاكل وتخلي المشروع قابل للتطوير لما يكبر وعدد الناس اللي بتشتغل عليه يزيد
